# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
anno = pd.read_csv("list_attr_celeba.csv")
anno.columns
# Out:
# Index(['image_id', '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive',
#        'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose',
#        'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows',
#        'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair',
#        'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open',
#        'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin',
#        'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns',
#        'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings',
#        'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace',
#        'Wearing_Necktie', 'Young'],
#       dtype='object')

# %%
anno["class_"]
for col in anno.columns:
# Out:
# <bound method Series.sort_index of Young
#  1    156734
# -1     45865
# Name: count, dtype: int64>
# <bound method Series.sort_index of Smiling
# -1    104930
#  1     97669
# Name: count, dtype: int64>
# <bound method Series.sort_index of Male
# -1    118165
#  1     84434
# Name: count, dtype: int64>
# <bound method Series.sort_index of Wearing_Hat
# -1    192781
#  1      9818
# Name: count, dtype: int64>
# <bound method Series.sort_index of Eyeglasses
# -1    189406
#  1     13193
# Name: count, dtype: int64>
# <bound method Series.sort_index of No_Beard
#  1    169158
# -1     33441
# Name: count, dtype: int64>
