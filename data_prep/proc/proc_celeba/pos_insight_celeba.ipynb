# %%
import pandas as pd
import os

# %%
df = pd.read_pickle("embeddings_celeba.pkl")
len(df)
# Out:
# 202307

# %%
df.columns
# Out:
# Index(['Filename', 'Face_embedding', '5_o_Clock_Shadow', 'Arched_Eyebrows',
#        'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips',
#        'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair',
#        'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee',
#        'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male',
#        'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard',
#        'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline',
#        'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair',
#        'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick',
#        'Wearing_Necklace', 'Wearing_Necktie', 'Young'],
#       dtype='object')

# %%
# a quantidade de mulheres supera a de homens em 33789 imagens faciais
df['Male'].value_counts()
print(118048 - 84259)
# Out:
# 33789

# %%
df_male_balanced = df[ ( df['Male'] == 1 ) | ( ( df['Male'] == -1).cumsum() <= 84259 )]

# %%
len(df_male_balanced[df_male_balanced['Male'] == 1])
# Out:
# 84259

# %%
df_male_balanced.to_pickle("male_balanced_embeddings_celeba.pkl")
