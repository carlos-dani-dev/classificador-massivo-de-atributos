# %%
import pandas as pd
import numpy as np

# %%
dataset_name = "casual"

df = pd.read_pickle(f"{dataset_name}_annotated.pkl")
print(df.columns)
df
# Out:
# Index(['face embedding', 'fitz_type', 'male'], dtype='object')
#                                            face embedding fitz_type      male
# 0       [-0.056425538, 0.07608479, -0.0044552353, -0.0...   type ii  not male
# 1       [-0.022688601, 0.07625579, 0.0068564517, -0.00...   type ii  not male
# 2       [-0.03247358, 0.07369421, 0.019010963, -0.0069...   type ii  not male
# 3       [-0.112932265, 0.05540906, -0.034106478, -0.02...   type ii  not male
# 4       [-0.05498392, 0.047582358, 0.030291582, -0.018...   type ii  not male
# ...                                                   ...       ...       ...
# 476767  [-0.018921476, -0.027326064, -0.033129293, 0.0...   type vi  not male
# 476768  [0.049484044, 0.04252539, -0.026328351, 0.0570...   type vi      male
# 476769  [0.019671299, -0.0076483237, 0.016461043, -0.0...   type vi      male
# 476770  [-0.009630375, -0.021176696, -0.02074587, 0.00...   type vi      male
# ...

# %%
df['fitz_type'].value_counts()
# Out:
# fitz_type
# type ii     97387
# type iii    32499
# type iv     17762
# type v       9756
# type i       8038
# type vi      3076
# Name: count, dtype: int64

# %%
df['Male'].value_counts()
# Out:
# Male
#  1    84259
# -1    84259
# Name: count, dtype: int64
